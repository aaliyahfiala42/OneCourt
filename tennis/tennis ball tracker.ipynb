# %%
import argparse
import queue
import pandas as pd 
import pickle
import imutils
import os
from PIL import Image, ImageDraw
import cv2 
import numpy as np
import torch
import sys
import time

#from sktime.datatypes._panel._convert import from_2d_array_to_nested
from Models.tracknet import trackNet
from utils import get_video_properties, get_dtype
#from detection import *
from pickle import load

# %%
input_video_path = 'VideoInput/video_input1.mp4'
output_video_path = 'VideoOutput/video_output_3frame.mp4'
minimap = 1
bounce = 0

# %%
n_classes = 256
save_weights_path = 'WeightsTracknet/model.1'
yolo_classes = 'Yolov3/yolov3.txt'
yolo_weights = 'Yolov3/yolov3.weights'
yolo_config = 'Yolov3/yolov3.cfg'

# %%
# get video fps&video size
video = cv2.VideoCapture(input_video_path)
fps = int(video.get(cv2.CAP_PROP_FPS))
print('fps : {}'.format(fps))
output_width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
output_height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
# Out:
# fps : 30

# %%
video
# Out:
# <VideoCapture 000001BBB85B05F0>

# %%
# try to determine the total number of frames in the video file
if imutils.is_cv2() is True :
    prop = cv2.cv.CV_CAP_PROP_FRAME_COUNT
else : 
    prop = cv2.CAP_PROP_FRAME_COUNT
total = int(video.get(prop))

# %%
# start from first frame
currentFrame = 0

# %%
# width and height in TrackNet
width, height = 640, 360
img, img1, img2 = None, None, None

# load TrackNet model
modelFN = trackNet
m = modelFN(n_classes, input_height=height, input_width=width)
m.compile(loss='categorical_crossentropy', optimizer='adadelta', metrics=['accuracy'])
m.load_weights(save_weights_path)
# Out:
# layer24 output shape: 256 360 640
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 3, 360, 640)]     0
#
#  conv2d_36 (Conv2D)          (None, 64, 360, 640)      1792
#
#  activation_38 (Activation)  (None, 64, 360, 640)      0
#
#  batch_normalization_36 (Bat  (None, 64, 360, 640)     2560
#  chNormalization)
#
#  conv2d_37 (Conv2D)          (None, 64, 360, 640)      36928
#
#  activation_39 (Activation)  (None, 64, 360, 640)      0
#
#  batch_normalization_37 (Bat  (None, 64, 360, 640)     2560
#  chNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 64, 180, 320)     0
#  2D)
#
#  conv2d_38 (Conv2D)          (None, 128, 180, 320)     73856
#
#  activation_40 (Activation)  (None, 128, 180, 320)     0
#
#  batch_normalization_38 (Bat  (None, 128, 180, 320)    1280
#  chNormalization)
#
#  conv2d_39 (Conv2D)          (None, 128, 180, 320)     147584
#
#  activation_41 (Activation)  (None, 128, 180, 320)     0
#
#  batch_normalization_39 (Bat  (None, 128, 180, 320)    1280
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 128, 90, 160)     0
#  2D)
#
#  conv2d_40 (Conv2D)          (None, 256, 90, 160)      295168
#
#  activation_42 (Activation)  (None, 256, 90, 160)      0
#
#  batch_normalization_40 (Bat  (None, 256, 90, 160)     640
#  chNormalization)
#
#  conv2d_41 (Conv2D)          (None, 256, 90, 160)      590080
#
#  activation_43 (Activation)  (None, 256, 90, 160)      0
#
#  batch_normalization_41 (Bat  (None, 256, 90, 160)     640
#  chNormalization)
#
#  conv2d_42 (Conv2D)          (None, 256, 90, 160)      590080
#
#  activation_44 (Activation)  (None, 256, 90, 160)      0
#
#  batch_normalization_42 (Bat  (None, 256, 90, 160)     640
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 256, 45, 80)      0
#  2D)
#
#  conv2d_43 (Conv2D)          (None, 512, 45, 80)       1180160
#
#  activation_45 (Activation)  (None, 512, 45, 80)       0
#
#  batch_normalization_43 (Bat  (None, 512, 45, 80)      320
#  chNormalization)
#
#  conv2d_44 (Conv2D)          (None, 512, 45, 80)       2359808
#
#  activation_46 (Activation)  (None, 512, 45, 80)       0
#
#  batch_normalization_44 (Bat  (None, 512, 45, 80)      320
#  chNormalization)
#
#  conv2d_45 (Conv2D)          (None, 512, 45, 80)       2359808
#
#  activation_47 (Activation)  (None, 512, 45, 80)       0
#
#  batch_normalization_45 (Bat  (None, 512, 45, 80)      320
#  chNormalization)
#
#  up_sampling2d_6 (UpSampling  (None, 512, 90, 160)     0
#  2D)
#
#  conv2d_46 (Conv2D)          (None, 256, 90, 160)      1179904
#
#  activation_48 (Activation)  (None, 256, 90, 160)      0
#
#  batch_normalization_46 (Bat  (None, 256, 90, 160)     640
#  chNormalization)
#
#  conv2d_47 (Conv2D)          (None, 256, 90, 160)      590080
#
#  activation_49 (Activation)  (None, 256, 90, 160)      0
#
#  batch_normalization_47 (Bat  (None, 256, 90, 160)     640
#  chNormalization)
#
#  conv2d_48 (Conv2D)          (None, 256, 90, 160)      590080
#
#  activation_50 (Activation)  (None, 256, 90, 160)      0
#
#  batch_normalization_48 (Bat  (None, 256, 90, 160)     640
#  chNormalization)
#
#  up_sampling2d_7 (UpSampling  (None, 256, 180, 320)    0
#  2D)
#
#  conv2d_49 (Conv2D)          (None, 128, 180, 320)     295040
#
#  activation_51 (Activation)  (None, 128, 180, 320)     0
#
#  batch_normalization_49 (Bat  (None, 128, 180, 320)    1280
#  chNormalization)
#
#  conv2d_50 (Conv2D)          (None, 128, 180, 320)     147584
#
#  activation_52 (Activation)  (None, 128, 180, 320)     0
#
#  batch_normalization_50 (Bat  (None, 128, 180, 320)    1280
#  chNormalization)
#
#  up_sampling2d_8 (UpSampling  (None, 128, 360, 640)    0
#  2D)
#
#  conv2d_51 (Conv2D)          (None, 64, 360, 640)      73792
#
#  activation_53 (Activation)  (None, 64, 360, 640)      0
#
#  batch_normalization_51 (Bat  (None, 64, 360, 640)     2560
#  chNormalization)
#
#  conv2d_52 (Conv2D)          (None, 64, 360, 640)      36928
#
#  activation_54 (Activation)  (None, 64, 360, 640)      0
#
#  batch_normalization_52 (Bat  (None, 64, 360, 640)     2560
#  chNormalization)
#
#  conv2d_53 (Conv2D)          (None, 256, 360, 640)     147712
#
#  activation_55 (Activation)  (None, 256, 360, 640)     0
#
#  batch_normalization_53 (Bat  (None, 256, 360, 640)    2560
#  chNormalization)
#
#  reshape_2 (Reshape)         (None, 256, 230400)       0
#
#  permute_2 (Permute)         (None, 230400, 256)       0
#
#  activation_56 (Activation)  (None, 230400, 256)       0
#
# =================================================================
# Total params: 10,719,104
# Trainable params: 10,707,744
# Non-trainable params: 11,360
# _________________________________________________________________

# %%
# In order to draw the trajectory of tennis, we need to save the coordinate of previous 7 frames
q = queue.deque()
for i in range(0, 4):
    q.appendleft(None)

# %%
# save prediction images as videos
fourcc = cv2.VideoWriter_fourcc(*'XVID')
output_video = cv2.VideoWriter(output_video_path, fourcc, fps, (output_width, output_height))

# %%
# get videos properties
fps, length, v_width, v_height = get_video_properties(video)

coords = []
frame_i = 0
frames = []
t = []

# %%
#define frames
while True:
    ret, frame = video.read()
    #sskipping court & player detection
    if ret:
        new_frame = cv2.resize(frame, (v_width, v_height))
        frames.append(new_frame)
    else:
        break

video.release()
print('Finished!')
# Out:
# Finished!

# %%
video = cv2.VideoCapture(input_video_path)
frame_i = 0

last = time.time() # start counting 
# while (True):
for img in frames:
    print('Tracking the ball: {}'.format(round( (currentFrame / total) * 100, 2)))
    frame_i += 1

    # detect the ball
    # img is the frame that TrackNet will predict the position
    # since we need to change the size and type of img, copy it to output_img
    output_img = img

    # resize it
    img = cv2.resize(img, (width, height))
    # input must be float type
    img = img.astype(np.float32)

    # since the odering of TrackNet  is 'channels_first', so we need to change the axis
    X = np.rollaxis(img, 2, 0)
    # prdict heatmap
    pr = m.predict(np.array([X]))[0]

    # since TrackNet output is ( net_output_height*model_output_width , n_classes )
    # so we need to reshape image as ( net_output_height, model_output_width , n_classes(depth) )
    pr = pr.reshape((height, width, n_classes)).argmax(axis=2)

    # cv2 image must be numpy.uint8, convert numpy.int64 to numpy.uint8
    pr = pr.astype(np.uint8)

    # reshape the image size as original input image
    heatmap = cv2.resize(pr, (output_width, output_height))

    # heatmap is converted into a binary image by threshold method.
    ret, heatmap = cv2.threshold(heatmap, 127, 255, cv2.THRESH_BINARY)

    # find the circle in image with 2<=radius<=7
    circles = cv2.HoughCircles(heatmap, cv2.HOUGH_GRADIENT, dp=1, minDist=1, param1=50, param2=2, minRadius=2,
                              maxRadius=7)

    
    #output_img = mark_player_box(output_img, player1_boxes, currentFrame-1)
    #output_img = mark_player_box(output_img, player2_boxes, currentFrame-1)

    PIL_image = cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB)
    PIL_image = Image.fromarray(PIL_image)

    # check if there have any tennis be detected
    if circles is not None:
        # if only one tennis be detected
        if len(circles) == 1:

            x = int(circles[0][0][0])
            y = int(circles[0][0][1])

            coords.append([x,y])
            t.append(time.time()-last)

            # push x,y to queue
            q.appendleft([x, y])
            # pop x,y from queue
            q.pop()

        else:
            coords.append(None)
            t.append(time.time()-last)
            # push None to queue
            q.appendleft(None)
            # pop x,y from queue
            q.pop()

    else:
        coords.append(None)
        t.append(time.time()-last)
        # push None to queue
        q.appendleft(None)
        # pop x,y from queue
        q.pop()

    # draw current frame prediction and previous 7 frames as yellow circle, total: 8 frames
    for i in range(0, 4):
        if q[i] is not None:
            draw_x = q[i][0]
            draw_y = q[i][1]
            bbox = (draw_x - 10, draw_y - 5, draw_x + 5, draw_y + 5)
            draw = ImageDraw.Draw(PIL_image)
            draw.ellipse(bbox, outline='red', fill = 'red')
            del draw

    # Convert PIL image format back to opencv image format
    opencvImage = cv2.cvtColor(np.array(PIL_image), cv2.COLOR_RGB2BGR)

    filename = 'C:/Users/aaliy/Desktop/Ball Tracking/CSE576_final_project/yolo3/tracknetoutputs/circled_' + str(frame_i) + '.jpg'    
    cv2.imwrite(filename, opencvImage)
    
    output_video.write(opencvImage)

    # next frame
    currentFrame += 1

# everything is done, release the video
#video.release()
#output_video.release()
# Out:
# Tracking the ball: 0.0
# 1/1 [==============================] - 0s 227ms/step
# Tracking the ball: 0.49
# 1/1 [==============================] - 0s 21ms/step
# Tracking the ball: 0.97
# 1/1 [==============================] - 0s 21ms/step
# Tracking the ball: 1.46
# 1/1 [==============================] - 0s 22ms/step
# Tracking the ball: 1.94
# 1/1 [==============================] - 0s 26ms/step
# Tracking the ball: 2.43
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 2.91
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 3.4
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 3.88
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 4.37
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 4.85
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 5.34
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 5.83
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 6.31
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 6.8
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 7.28
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 7.77
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 8.25
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 8.74
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 9.22
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 9.71
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 10.19
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 10.68
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 11.17
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 11.65
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 12.14
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 12.62
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 13.11
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 13.59
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 14.08
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 14.56
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 15.05
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 15.53
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 16.02
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 16.5
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 16.99
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 17.48
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 17.96
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 18.45
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 18.93
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 19.42
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 19.9
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 20.39
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 20.87
# 1/1 [==============================] - 0s 18ms/step
# Tracking the ball: 21.36
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 21.84
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 22.33
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 22.82
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 23.3
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 23.79
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 24.27
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 24.76
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 25.24
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 25.73
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 26.21
# 1/1 [==============================] - 0s 18ms/step
# Tracking the ball: 26.7
# 1/1 [==============================] - 0s 18ms/step
# Tracking the ball: 27.18
# 1/1 [==============================] - 0s 18ms/step
# Tracking the ball: 27.67
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 28.16
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 28.64
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 29.13
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 29.61
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 30.1
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 30.58
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 31.07
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 31.55
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 32.04
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 32.52
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 33.01
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 33.5
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 33.98
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 34.47
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 34.95
# 1/1 [==============================] - 0s 18ms/step
# Tracking the ball: 35.44
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 35.92
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 36.41
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 36.89
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 37.38
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 37.86
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 38.35
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 38.83
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 39.32
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 39.81
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 40.29
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 40.78
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 41.26
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 41.75
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 42.23
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 42.72
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 43.2
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 43.69
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 44.17
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 44.66
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 45.15
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 45.63
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 46.12
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 46.6
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 47.09
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 47.57
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 48.06
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 48.54
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 49.03
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 49.51
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 50.0
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 50.49
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 50.97
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 51.46
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 51.94
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 52.43
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 52.91
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 53.4
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 53.88
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 54.37
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 54.85
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 55.34
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 55.83
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 56.31
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 56.8
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 57.28
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 57.77
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 58.25
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 58.74
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 59.22
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 59.71
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 60.19
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 60.68
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 61.17
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 61.65
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 62.14
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 62.62
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 63.11
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 63.59
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 64.08
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 64.56
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 65.05
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 65.53
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 66.02
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 66.5
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 66.99
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 67.48
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 67.96
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 68.45
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 68.93
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 69.42
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 69.9
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 70.39
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 70.87
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 71.36
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 71.84
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 72.33
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 72.82
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 73.3
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 73.79
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 74.27
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 74.76
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 75.24
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 75.73
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 76.21
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 76.7
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 77.18
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 77.67
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 78.16
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 78.64
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 79.13
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 79.61
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 80.1
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 80.58
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 81.07
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 81.55
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 82.04
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 82.52
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 83.01
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 83.5
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 83.98
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 84.47
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 84.95
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 85.44
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 85.92
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 86.41
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 86.89
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 87.38
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 87.86
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 88.35
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 88.83
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 89.32
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 89.81
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 90.29
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 90.78
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 91.26
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 91.75
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 92.23
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 92.72
# 1/1 [==============================] - 0s 17ms/step
# Tracking the ball: 93.2
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 93.69
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 94.17
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 94.66
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 95.15
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 95.63
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 96.12
# 1/1 [==============================] - 0s 15ms/step
# Tracking the ball: 96.6
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 97.09
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 97.57
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 98.06
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 98.54
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 99.03
# 1/1 [==============================] - 0s 16ms/step
# Tracking the ball: 99.51
# 1/1 [==============================] - 0s 16ms/step

# %%
output_video
# Out:
# <VideoWriter 000001BB96676830>

# %%
output_width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
output_height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(video.get(cv2.CAP_PROP_FPS))
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
fourcc = cv2.VideoWriter_fourcc(*'XVID')

print(fps)
print(length)
# Out:
# 30
# 206

# %%
xy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2592/3424147140.py in <module>
# ----> 1 xy
#
# NameError: name 'xy' is not defined

# %%
output_video = cv2.VideoWriter('VideoOutput/final_video.mp4', fourcc, fps, (output_width, output_height))
i = 0
while True:
    ret, frame = video.read()
    if ret:
        # if coords[i] is not None:
        if i in idx:
            center_coordinates = int(xy[i][0]), int(xy[i][1])
            radius = 3
            color = (255, 0, 0)
            thickness = -1
            cv2.circle(frame, center_coordinates, 10, color, thickness)
        i += 1
        output_video.write(frame)
    else:
        break

video.release()
output_video.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2592/3237017103.py in <module>
#       5     if ret:
#       6         # if coords[i] is not None:
# ----> 7         if i in idx:
#       8             center_coordinates = int(xy[i][0]), int(xy[i][1])
#       9             radius = 3
#
# NameError: name 'idx' is not defined

# %%
  output_width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
  output_height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
  fps = int(video.get(cv2.CAP_PROP_FPS))
  length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
  fourcc = cv2.VideoWriter_fourcc(*'XVID')

  print(fps)
  print(length)

  output_video = cv2.VideoWriter('VideoOutput/final_video.mp4', fourcc, fps, (output_width, output_height))
  i = 0
  while True:
    ret, frame = video.read()
    if ret:
      # if coords[i] is not None:
      if i in idx:
        center_coordinates = int(xy[i][0]), int(xy[i][1])
        radius = 3
        color = (255, 0, 0)
        thickness = -1
        cv2.circle(frame, center_coordinates, 10, color, thickness)
      i += 1
      output_video.write(frame)
    else:
      break

  video.release()
  output_video.release()

# %%
video = cv2.VideoCapture(input_video_path)
frame_i = 0

last = time.time() # start counting 
# while (True):
for img in frames:
    print('Tracking the ball: {}'.format(round( (currentFrame / total) * 100, 2)))
    frame_i += 1

    # detect the ball
    # img is the frame that TrackNet will predict the position
    # since we need to change the size and type of img, copy it to output_img
    output_img = img

    # resize it
    img = cv2.resize(img, (width, height))
    # input must be float type
    img = img.astype(np.float32)

    # since the odering of TrackNet  is 'channels_first', so we need to change the axis
    X = np.rollaxis(img, 2, 0)
    # prdict heatmap
    pr = m.predict(np.array([X]))[0]

    # since TrackNet output is ( net_output_height*model_output_width , n_classes )
    # so we need to reshape image as ( net_output_height, model_output_width , n_classes(depth) )
    pr = pr.reshape((height, width, n_classes)).argmax(axis=2)

    # cv2 image must be numpy.uint8, convert numpy.int64 to numpy.uint8
    pr = pr.astype(np.uint8)

    # reshape the image size as original input image
    heatmap = cv2.resize(pr, (output_width, output_height))

    # heatmap is converted into a binary image by threshold method.
    ret, heatmap = cv2.threshold(heatmap, 127, 255, cv2.THRESH_BINARY)

    # find the circle in image with 2<=radius<=7
    circles = cv2.HoughCircles(heatmap, cv2.HOUGH_GRADIENT, dp=1, minDist=1, param1=50, param2=2, minRadius=2,
                              maxRadius=7)


    output_img = mark_player_box(output_img, player1_boxes, currentFrame-1)
    output_img = mark_player_box(output_img, player2_boxes, currentFrame-1)
    
    PIL_image = cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB)
    PIL_image = Image.fromarray(PIL_image)

    # check if there have any tennis be detected
    if circles is not None:
        # if only one tennis be detected
        if len(circles) == 1:

            x = int(circles[0][0][0])
            y = int(circles[0][0][1])

            coords.append([x,y])
            t.append(time.time()-last)

            # push x,y to queue
            q.appendleft([x, y])
            # pop x,y from queue
            q.pop()

        else:
            coords.append(None)
            t.append(time.time()-last)
            # push None to queue
            q.appendleft(None)
            # pop x,y from queue
            q.pop()

    else:
        coords.append(None)
        t.append(time.time()-last)
        # push None to queue
        q.appendleft(None)
        # pop x,y from queue
        q.pop()

    # draw current frame prediction and previous 7 frames as yellow circle, total: 8 frames
    for i in range(0, 8):
        if q[i] is not None:
            draw_x = q[i][0]
            draw_y = q[i][1]
            bbox = (draw_x - 2, draw_y - 2, draw_x + 2, draw_y + 2)
            draw = ImageDraw.Draw(PIL_image)
            draw.ellipse(bbox, outline='yellow')
            del draw

    # Convert PIL image format back to opencv image format
    opencvImage = cv2.cvtColor(np.array(PIL_image), cv2.COLOR_RGB2BGR)

    output_video.write(opencvImage)

    # next frame
    currentFrame += 1

# everything is done, release the video
video.release()
output_video.release()

if minimap == 1:
  game_video = cv2.VideoCapture(output_video_path)

  fps1 = int(game_video.get(cv2.CAP_PROP_FPS))

  output_width = int(game_video.get(cv2.CAP_PROP_FRAME_WIDTH))
  output_height = int(game_video.get(cv2.CAP_PROP_FRAME_HEIGHT))
  print('game ', fps1)
  output_video = cv2.VideoWriter('VideoOutput/video_with_map.mp4', fourcc, fps, (output_width, output_height))
  
  print('Adding the mini-map...')

  # Remove Outliers 
  x, y = diff_xy(coords)
  remove_outliers(x, y, coords)
  # Interpolation
  coords = interpolation(coords)
  create_top_view(court_detector, detection_model, coords, fps)
  minimap_video = cv2.VideoCapture('VideoOutput/minimap.mp4')
  fps2 = int(minimap_video.get(cv2.CAP_PROP_FPS))
  print('minimap ', fps2)
  while True:
    ret, frame = game_video.read()
    ret2, img = minimap_video.read()
    if ret:
      output = merge(frame, img)
      output_video.write(output)
    else:
      break
  game_video.release()
  minimap_video.release()

output_video.release()

for _ in range(3):
  x, y = diff_xy(coords)
  remove_outliers(x, y, coords)

# interpolation
coords = interpolation(coords)

# velocty 
Vx = []
Vy = []
V = []
frames = [*range(len(coords))]

for i in range(len(coords)-1):
  p1 = coords[i]
  p2 = coords[i+1]
  t1 = t[i]
  t2 = t[i+1]
  x = (p1[0]-p2[0])/(t1-t2)
  y = (p1[1]-p2[1])/(t1-t2)
  Vx.append(x)
  Vy.append(y)

for i in range(len(Vx)):
  vx = Vx[i]
  vy = Vy[i]
  v = (vx**2+vy**2)**0.5
  V.append(v)

xy = coords[:]

if bounce == 1:
  # Predicting Bounces 
  test_df = pd.DataFrame({'x': [coord[0] for coord in xy[:-1]], 'y':[coord[1] for coord in xy[:-1]], 'V': V})

  # df.shift
  for i in range(20, 0, -1): 
    test_df[f'lagX_{i}'] = test_df['x'].shift(i, fill_value=0)
  for i in range(20, 0, -1): 
    test_df[f'lagY_{i}'] = test_df['y'].shift(i, fill_value=0)
  for i in range(20, 0, -1): 
    test_df[f'lagV_{i}'] = test_df['V'].shift(i, fill_value=0)

  test_df.drop(['x', 'y', 'V'], 1, inplace=True)

  Xs = test_df[['lagX_20', 'lagX_19', 'lagX_18', 'lagX_17', 'lagX_16',
        'lagX_15', 'lagX_14', 'lagX_13', 'lagX_12', 'lagX_11', 'lagX_10',
        'lagX_9', 'lagX_8', 'lagX_7', 'lagX_6', 'lagX_5', 'lagX_4', 'lagX_3',
        'lagX_2', 'lagX_1']]
  Xs = from_2d_array_to_nested(Xs.to_numpy())

  Ys = test_df[['lagY_20', 'lagY_19', 'lagY_18', 'lagY_17',
        'lagY_16', 'lagY_15', 'lagY_14', 'lagY_13', 'lagY_12', 'lagY_11',
        'lagY_10', 'lagY_9', 'lagY_8', 'lagY_7', 'lagY_6', 'lagY_5', 'lagY_4',
        'lagY_3', 'lagY_2', 'lagY_1']]
  Ys = from_2d_array_to_nested(Ys.to_numpy())

  Vs = test_df[['lagV_20', 'lagV_19', 'lagV_18',
        'lagV_17', 'lagV_16', 'lagV_15', 'lagV_14', 'lagV_13', 'lagV_12',
        'lagV_11', 'lagV_10', 'lagV_9', 'lagV_8', 'lagV_7', 'lagV_6', 'lagV_5',
        'lagV_4', 'lagV_3', 'lagV_2', 'lagV_1']]
  Vs = from_2d_array_to_nested(Vs.to_numpy())

  X = pd.concat([Xs, Ys, Vs], 1)

  # load the pre-trained classifier  
  clf = load(open('clf.pkl', 'rb'))

  predcted = clf.predict(X)
  idx = list(np.where(predcted == 1)[0])
  idx = np.array(idx) - 10
  
  if minimap == 1:
    video = cv2.VideoCapture('VideoOutput/video_with_map.mp4')
  else:
    video = cv2.VideoCapture(output_video_path)

  output_width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
  output_height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
  fps = int(video.get(cv2.CAP_PROP_FPS))
  length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
  fourcc = cv2.VideoWriter_fourcc(*'XVID')

  print(fps)
  print(length)

  output_video = cv2.VideoWriter('VideoOutput/final_video.mp4', fourcc, fps, (output_width, output_height))
  i = 0
  while True:
    ret, frame = video.read()
    if ret:
      # if coords[i] is not None:
      if i in idx:
        center_coordinates = int(xy[i][0]), int(xy[i][1])
        radius = 3
        color = (255, 0, 0)
        thickness = -1
        cv2.circle(frame, center_coordinates, 10, color, thickness)
      i += 1
      output_video.write(frame)
    else:
      break

  video.release()
  output_video.release()

# %%
# load yolov3 labels
LABELS = open(yolo_classes).read().strip().split("\n")
# yolo net
net = cv2.dnn.readNet(yolo_weights, yolo_config)

# court
court_detector = CourtDetector()

# players tracker
dtype = get_dtype()
detection_model = DetectionModel(dtype=dtype)

# get videos properties
fps, length, v_width, v_height = get_video_properties(video)

coords = []
frame_i = 0
frames = []
t = []

while True:
  ret, frame = video.read()
  frame_i += 1

  if ret:
    if frame_i == 1:
      print('Detecting the court and the players...')
      lines = court_detector.detect(frame)
    else: # then track it
      lines = court_detector.track_court(frame)
    detection_model.detect_player_1(frame, court_detector)
    detection_model.detect_top_persons(frame, court_detector, frame_i)
    
    for i in range(0, len(lines), 4):
      x1, y1, x2, y2 = lines[i],lines[i+1], lines[i+2], lines[i+3]
      cv2.line(frame, (int(x1),int(y1)),(int(x2),int(y2)), (0,0,255), 5)
    new_frame = cv2.resize(frame, (v_width, v_height))
    frames.append(new_frame)
  else:
    break
video.release()
print('Finished!')

detection_model.find_player_2_box()

# second part 
player1_boxes = detection_model.player_1_boxes
player2_boxes = detection_model.player_2_boxes

video = cv2.VideoCapture(input_video_path)
frame_i = 0

last = time.time() # start counting 
# while (True):
for img in frames:
    print('Tracking the ball: {}'.format(round( (currentFrame / total) * 100, 2)))
    frame_i += 1

    # detect the ball
    # img is the frame that TrackNet will predict the position
    # since we need to change the size and type of img, copy it to output_img
    output_img = img

    # resize it
    img = cv2.resize(img, (width, height))
    # input must be float type
    img = img.astype(np.float32)

    # since the odering of TrackNet  is 'channels_first', so we need to change the axis
    X = np.rollaxis(img, 2, 0)
    # prdict heatmap
    pr = m.predict(np.array([X]))[0]

    # since TrackNet output is ( net_output_height*model_output_width , n_classes )
    # so we need to reshape image as ( net_output_height, model_output_width , n_classes(depth) )
    pr = pr.reshape((height, width, n_classes)).argmax(axis=2)

    # cv2 image must be numpy.uint8, convert numpy.int64 to numpy.uint8
    pr = pr.astype(np.uint8)

    # reshape the image size as original input image
    heatmap = cv2.resize(pr, (output_width, output_height))

    # heatmap is converted into a binary image by threshold method.
    ret, heatmap = cv2.threshold(heatmap, 127, 255, cv2.THRESH_BINARY)

    # find the circle in image with 2<=radius<=7
    circles = cv2.HoughCircles(heatmap, cv2.HOUGH_GRADIENT, dp=1, minDist=1, param1=50, param2=2, minRadius=2,
                              maxRadius=7)


    output_img = mark_player_box(output_img, player1_boxes, currentFrame-1)
    output_img = mark_player_box(output_img, player2_boxes, currentFrame-1)
    
    PIL_image = cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB)
    PIL_image = Image.fromarray(PIL_image)

    # check if there have any tennis be detected
    if circles is not None:
        # if only one tennis be detected
        if len(circles) == 1:

            x = int(circles[0][0][0])
            y = int(circles[0][0][1])

            coords.append([x,y])
            t.append(time.time()-last)

            # push x,y to queue
            q.appendleft([x, y])
            # pop x,y from queue
            q.pop()

        else:
            coords.append(None)
            t.append(time.time()-last)
            # push None to queue
            q.appendleft(None)
            # pop x,y from queue
            q.pop()

    else:
        coords.append(None)
        t.append(time.time()-last)
        # push None to queue
        q.appendleft(None)
        # pop x,y from queue
        q.pop()

    # draw current frame prediction and previous 7 frames as yellow circle, total: 8 frames
    for i in range(0, 8):
        if q[i] is not None:
            draw_x = q[i][0]
            draw_y = q[i][1]
            bbox = (draw_x - 2, draw_y - 2, draw_x + 2, draw_y + 2)
            draw = ImageDraw.Draw(PIL_image)
            draw.ellipse(bbox, outline='yellow')
            del draw

    # Convert PIL image format back to opencv image format
    opencvImage = cv2.cvtColor(np.array(PIL_image), cv2.COLOR_RGB2BGR)

    output_video.write(opencvImage)

    # next frame
    currentFrame += 1

# everything is done, release the video
video.release()
output_video.release()

if minimap == 1:
  game_video = cv2.VideoCapture(output_video_path)

  fps1 = int(game_video.get(cv2.CAP_PROP_FPS))

  output_width = int(game_video.get(cv2.CAP_PROP_FRAME_WIDTH))
  output_height = int(game_video.get(cv2.CAP_PROP_FRAME_HEIGHT))
  print('game ', fps1)
  output_video = cv2.VideoWriter('VideoOutput/video_with_map.mp4', fourcc, fps, (output_width, output_height))
  
  print('Adding the mini-map...')

  # Remove Outliers 
  x, y = diff_xy(coords)
  remove_outliers(x, y, coords)
  # Interpolation
  coords = interpolation(coords)
  create_top_view(court_detector, detection_model, coords, fps)
  minimap_video = cv2.VideoCapture('VideoOutput/minimap.mp4')
  fps2 = int(minimap_video.get(cv2.CAP_PROP_FPS))
  print('minimap ', fps2)
  while True:
    ret, frame = game_video.read()
    ret2, img = minimap_video.read()
    if ret:
      output = merge(frame, img)
      output_video.write(output)
    else:
      break
  game_video.release()
  minimap_video.release()

output_video.release()

for _ in range(3):
  x, y = diff_xy(coords)
  remove_outliers(x, y, coords)

# interpolation
coords = interpolation(coords)

# velocty 
Vx = []
Vy = []
V = []
frames = [*range(len(coords))]

for i in range(len(coords)-1):
  p1 = coords[i]
  p2 = coords[i+1]
  t1 = t[i]
  t2 = t[i+1]
  x = (p1[0]-p2[0])/(t1-t2)
  y = (p1[1]-p2[1])/(t1-t2)
  Vx.append(x)
  Vy.append(y)

for i in range(len(Vx)):
  vx = Vx[i]
  vy = Vy[i]
  v = (vx**2+vy**2)**0.5
  V.append(v)

xy = coords[:]

if bounce == 1:
  # Predicting Bounces 
  test_df = pd.DataFrame({'x': [coord[0] for coord in xy[:-1]], 'y':[coord[1] for coord in xy[:-1]], 'V': V})

  # df.shift
  for i in range(20, 0, -1): 
    test_df[f'lagX_{i}'] = test_df['x'].shift(i, fill_value=0)
  for i in range(20, 0, -1): 
    test_df[f'lagY_{i}'] = test_df['y'].shift(i, fill_value=0)
  for i in range(20, 0, -1): 
    test_df[f'lagV_{i}'] = test_df['V'].shift(i, fill_value=0)

  test_df.drop(['x', 'y', 'V'], 1, inplace=True)

  Xs = test_df[['lagX_20', 'lagX_19', 'lagX_18', 'lagX_17', 'lagX_16',
        'lagX_15', 'lagX_14', 'lagX_13', 'lagX_12', 'lagX_11', 'lagX_10',
        'lagX_9', 'lagX_8', 'lagX_7', 'lagX_6', 'lagX_5', 'lagX_4', 'lagX_3',
        'lagX_2', 'lagX_1']]
  Xs = from_2d_array_to_nested(Xs.to_numpy())

  Ys = test_df[['lagY_20', 'lagY_19', 'lagY_18', 'lagY_17',
        'lagY_16', 'lagY_15', 'lagY_14', 'lagY_13', 'lagY_12', 'lagY_11',
        'lagY_10', 'lagY_9', 'lagY_8', 'lagY_7', 'lagY_6', 'lagY_5', 'lagY_4',
        'lagY_3', 'lagY_2', 'lagY_1']]
  Ys = from_2d_array_to_nested(Ys.to_numpy())

  Vs = test_df[['lagV_20', 'lagV_19', 'lagV_18',
        'lagV_17', 'lagV_16', 'lagV_15', 'lagV_14', 'lagV_13', 'lagV_12',
        'lagV_11', 'lagV_10', 'lagV_9', 'lagV_8', 'lagV_7', 'lagV_6', 'lagV_5',
        'lagV_4', 'lagV_3', 'lagV_2', 'lagV_1']]
  Vs = from_2d_array_to_nested(Vs.to_numpy())

  X = pd.concat([Xs, Ys, Vs], 1)

  # load the pre-trained classifier  
  clf = load(open('clf.pkl', 'rb'))

  predcted = clf.predict(X)
  idx = list(np.where(predcted == 1)[0])
  idx = np.array(idx) - 10
  
  if minimap == 1:
    video = cv2.VideoCapture('VideoOutput/video_with_map.mp4')
  else:
    video = cv2.VideoCapture(output_video_path)

  output_width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
  output_height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
  fps = int(video.get(cv2.CAP_PROP_FPS))
  length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
  fourcc = cv2.VideoWriter_fourcc(*'XVID')

  print(fps)
  print(length)

  output_video = cv2.VideoWriter('VideoOutput/final_video.mp4', fourcc, fps, (output_width, output_height))
  i = 0
  while True:
    ret, frame = video.read()
    if ret:
      # if coords[i] is not None:
      if i in idx:
        center_coordinates = int(xy[i][0]), int(xy[i][1])
        radius = 3
        color = (255, 0, 0)
        thickness = -1
        cv2.circle(frame, center_coordinates, 10, color, thickness)
      i += 1
      output_video.write(frame)
    else:
      break

  video.release()
  output_video.release()
